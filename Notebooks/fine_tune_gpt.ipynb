# %% [markdown]
# ##### Kaggle Dataset

# %%
# !pip install kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d thedevastator/synthetic-therapy-conversations-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thedevastator/synthetic-therapy-conversations-dataset
# License(s): CC0-1.0
# synthetic-therapy-conversations-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/synthetic-therapy-conversations-dataset.zip
# Out:
# Archive:  /content/synthetic-therapy-conversations-dataset.zip
# replace train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: train.csv

# %%
import requests
import pandas as pd
# URL of the JSON file
url = "https://storage.googleapis.com/kagglesdsdata/datasets/2594075/4429121/intents.json?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240824%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240824T082131Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

# Request the data from the URL
response = requests.get(url)
data = response.json()

# Convert the intents into a DataFrame
df_kaggle_1 = pd.DataFrame(data['intents'])

# %%
df_kaggle_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tag        80 non-null     object
#  1   patterns   80 non-null     object
#  2   responses  80 non-null     object
# dtypes: object(3)
# memory usage: 2.0+ KB

# %%
df_kaggle_1 = df_kaggle_1.rename(columns={'patterns': 'client', 'responses': 'therapist'})
df_kaggle_1.drop('tag', axis=1, inplace=True)

# %%
df_kaggle_1.head()
# Out:
#                                               client  \
# 0  [Hi, Hey, Is anyone there?, Hi there, Hello, H...
# 1                                     [Good morning]
# 2                                   [Good afternoon]
# 3                                     [Good evening]
# 4                                       [Good night]
#
#                                            therapist
# 0  [Hello there. Tell me how are you feeling toda...
# 1  [Good morning. I hope you had a good night's s...
# 2           [Good afternoon. How is your day going?]
# 3             [Good evening. How has your day been?]
# 4  [Good night. Get some proper sleep, Good night...

# %% [markdown]
# ##### Hugging Face Dataset

# %%
import pandas as pd

# %%
df_hf = pd.read_json("hf://datasets/Amod/mental_health_counseling_conversations/combined_dataset.json", lines=True)

# %%
df_hf = df_hf.rename(columns={'Context': 'client', 'Response': 'therapist'})

# %%
df_hf.head()
# Out:
#                                               client  \
# 0  I'm going through some things with my feelings...
# 1  I'm going through some things with my feelings...
# 2  I'm going through some things with my feelings...
# 3  I'm going through some things with my feelings...
# 4  I'm going through some things with my feelings...
#
#                                            therapist
# 0  If everyone thinks you're worthless, then mayb...
# 1  Hello, and thank you for your question and see...
# 2  First thing I'd suggest is getting the sleep y...
# 3  Therapy is essential for those that are feelin...
# 4  I first want to let you know that you are not ...

# %%
df_hf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3512 entries, 0 to 3511
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client     3512 non-null   object
#  1   therapist  3512 non-null   object
# dtypes: object(2)
# memory usage: 55.0+ KB

# %% [markdown]
# ##### Github Dataset

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=34fbede46c8a1f5342321a93450b4792874169a7993ce5ea46ad1581580712ff
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
import wget

url = 'https://raw.githubusercontent.com/uccollab/AnnoMI/main/AnnoMI-full.csv'
wget.download(url, 'AnnoMI-full.csv')
# Out:
# 'AnnoMI-full.csv'

# %%
df_github = pd.read_csv('AnnoMI-full.csv')

# %%
df_github.value_counts("topic")
# Out:
# topic
# reducing alcohol consumption                                                          2326
# more exercise / increasing activity                                                   2034
# reducing recidivism                                                                   1303
# reducing drug use                                                                     1104
# diabetes management                                                                    948
# smoking cessation                                                                      923
# smoking cessation                                                                      541
# taking medicine / following medical procedure                                          448
# asthma management                                                                      431
# avoiding DOI                                                                           394
# ...

# %%
df_github.columns
# Out:
# Index(['mi_quality', 'transcript_id', 'video_title', 'video_url', 'topic',
#        'utterance_id', 'interlocutor', 'timestamp', 'utterance_text',
#        'annotator_id', 'therapist_input_exists', 'therapist_input_subtype',
#        'reflection_exists', 'reflection_subtype', 'question_exists',
#        'question_subtype', 'main_therapist_behaviour', 'client_talk_type'],
#       dtype='object')

# %%
df_github.drop(['mi_quality','transcript_id', 'video_title', 'video_url',
       'utterance_id', 'timestamp',
       'annotator_id', 'therapist_input_exists', 'therapist_input_subtype',
       'reflection_exists', 'reflection_subtype', 'question_exists',
       'question_subtype', 'main_therapist_behaviour', 'client_talk_type'], axis=1, inplace=True)

# %%
# Initialize lists to store dialogues
client_dialogues = []
therapist_dialogues = []

# Iterate through the DataFrame and populate the lists
for i in range(len(df_github) - 1):
    if df_github.loc[i, 'interlocutor'] == 'client' and df_github.loc[i + 1, 'interlocutor'] == 'therapist':
        client_dialogues.append(df_github.loc[i, 'utterance_text'])
        therapist_dialogues.append(df_github.loc[i + 1, 'utterance_text'])

# Create a new DataFrame with the desired format
df_github_new = pd.DataFrame({
    'client_column': client_dialogues,
    'therapist_column': therapist_dialogues
})

# %%
df_github = df_github_new.rename(columns={'client_column': 'client', 'therapist_column': 'therapist'})

# %%
df_github.head()
# Out:
#                                       client  \
# 0                                      Sure.
# 1                                    Mm-hmm.
# 2  Usually three drinks and glasses of wine.
# 3                       Something like that.
# 4                                      Okay.
#
#                                            therapist
# 0  So, let's see. It looks that you put-- You dri...
# 1  -and you usually have three to four drinks whe...
# 2            Okay. That's at least 12 drinks a week.
# 3  Okay. Just so you know, my role, um, when we t...
# 4  Uh, what else can you tell me about your drink...

# %% [markdown]
# #### Combining the dataframes

# %%
# Extract and concatenate the 'client' columns from all datasets
clients_combined = pd.concat([
    df_kaggle_1[['client']],
    df_hf[['client']],
    # df_github[['client']]
], ignore_index=True)

# Extract and concatenate the 'therapist' columns from all datasets
therapists_combined = pd.concat([
    df_kaggle_1[['therapist']],
    df_hf[['therapist']],
    # df_github[['therapist']]
], ignore_index=True)

# Combine the concatenated client and therapist columns into a single DataFrame
combined_df = pd.DataFrame({
    'client': clients_combined['client'],
    'therapist': therapists_combined['therapist']
})

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3592 entries, 0 to 3591
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client     3592 non-null   object
#  1   therapist  3592 non-null   object
# dtypes: object(2)
# memory usage: 56.2+ KB

# %%
combined_df = combined_df.sample(frac=1, random_state=42).reset_index(drop=True) #shuffle the data

# %%
combined_df.head()
# Out:
#                                               client  \
# 0              After I told them, they yelled at me.
# 1  He said he would try and he never did. It's be...
# 2    How does a person start the counseling process?
# 3  I have a friend that who I used to be in a rel...
# 4  I have anxieties about everyday stressors, i.e...
#
#                                            therapist
# 0  Hello, and thank you for your question. I am v...
# 1  Although the marriage vows say in sickness and...
# 2  Starting the counseling process can be dauntin...
# 3  Hello. There are a number of factors playing i...
# 4  Anxieties are an adrenal problem;Clean them ou...

# %% [markdown]
# ##Preprocessing

# %% [markdown]
# #### Lower Casing

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize

def lower(df, columns_to_lowercase):
    for column in columns_to_lowercase:
        if column in df.columns:
            # Tokenize each entry in the column
            combined_df[column] = combined_df[column].apply(lambda x: [token.lower() for token in x] if isinstance(x, list) else x.lower())
        else:
            print(f"Column '{column}' not found in DataFrame.")
    return combined_df

# %%
df = lower(combined_df, ["client","therapist"])
df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3592 entries, 0 to 3591
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client     3592 non-null   object
#  1   therapist  3592 non-null   object
# dtypes: object(2)
# memory usage: 56.2+ KB

# %% [markdown]
# ##Gpt Fine Tuning

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# ...

# %%
from datasets import Dataset
from transformers import AutoTokenizer

# %%
df['client'] = df['client'].apply(lambda x: ' '.join(x) if isinstance(x, list) else str(x))
df['therapist'] = df['therapist'].apply(lambda x: ' '.join(x) if isinstance(x, list) else str(x))

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")

dataset = Dataset.from_pandas(df)

# Add a padding token to the tokenizer
tokenizer.pad_token = tokenizer.eos_token
tokenizer.pad_token_id = tokenizer.eos_token_id

def tokenize_fn(example):
    return tokenizer(example["client"], example["therapist"], truncation= True, padding='longest')


tokenized_dataset = dataset.map(tokenize_fn, batched=True)
# Out:
# Map:   0%|          | 0/3592 [00:00<?, ? examples/s]

# %%
# Split dataset into training and validation sets
split_dataset = tokenized_dataset.train_test_split(test_size=0.1)
train_dataset = split_dataset['train']
eval_dataset = split_dataset['test']

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False  # This is for causal language modeling (like GPT-2)
)

# %%
from torch.utils.data import DataLoader
from datasets import load_dataset

train_dataloader = DataLoader(
    tokenized_dataset,
    shuffle=True,
    batch_size=2,
    collate_fn=data_collator
)

eval_dataloader = DataLoader(
    eval_dataset,
    batch_size=4,
    collate_fn=data_collator
)

# %%
from transformers import AutoModelForCausalLM, Trainer, TrainingArguments

model = AutoModelForCausalLM.from_pretrained("gpt2")

training_args = TrainingArguments(
    per_device_train_batch_size=2,  # Reduced batch size
    gradient_accumulation_steps=4,  # Accumulate gradients
    num_train_epochs=5,
    logging_dir="./logs",
    output_dir="./results",
    eval_strategy="epoch",  # Updated to eval_strategy
    save_strategy="epoch",
    learning_rate=3e-5,
    weight_decay=0.01,
    warmup_steps=500,
    logging_steps=100,
    load_best_model_at_end=True,
    metric_for_best_model="loss",
    greater_is_better=False,
    fp16=True  # Mixed precision training
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset
)

trainer.train()
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-43-ae5bccb713cb> in <cell line: 31>()
#      29 )
#      30
# ---> 31 trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1930                 hf_hub_utils.enable_progress_bars()
#    1931         else:
# -> 1932             return inner_training_loop(
#    1933                 args=args,
#    1934                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2266
#    2267                 with self.accelerator.accumulate(model):
# -> 2268                     tr_loss_step = self.training_step(model, inputs)
#    2269
# ...

# %%
trainer.save_model("./results")
tokenizer.save_pretrained("./results")
# Out:
# ('./results/tokenizer_config.json',
#  './results/special_tokens_map.json',
#  './results/vocab.json',
#  './results/merges.txt',
#  './results/added_tokens.json',
#  './results/tokenizer.json')

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

def generate_text(prompt, model, tokenizer, max_length=200):
    # Tokenize the input prompt
    input_ids = tokenizer.encode(prompt, return_tensors='pt')

    # Generate text
    outputs = model.generate(
        input_ids,
        max_length=max_length,
        num_return_sequences=1,  # Number of sequences to return
        do_sample=True,  # Enable sampling
        top_p=0.95,  # Nucleus sampling
        top_k=50,  # Top-k sampling
        temperature=0.7,  # Sampling temperature
        pad_token_id=tokenizer.eos_token_id  # Set padding token to be the same as eos token
    )

    # Decode the generated text
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_text

# Load the model and tokenizer
model = AutoModelForCausalLM.from_pretrained("./results")
tokenizer = AutoTokenizer.from_pretrained("gpt2")

# Example prompt
prompt = "Once upon a time in a land far, far away,"
generated_text = generate_text(prompt, model, tokenizer, max_length=200)
print(generated_text)
# Out:
# Once upon a time in a land far, far away, there was a man named Robb who seemed to know all the words to those words. He did not seem to know the Dothraki. The Hand could not comprehend what he said.  This is my brother Robb,  he said in the old Dothraki tongue,  who killed my father in a duel, and who will never see me again. What kind of man would kill a king who took the life of his father?  He spoke a common language, yet his words did not quite match the words of the Dothraki, and for a time they did not seem to understand him. Yet somehow he did.  This is my son,  he said as he spoke them.  The Hand has no sons. He is only a shadow of his father's likeness.  Robb looked up and saw his father standing before them.  He is the last of my line of defense. He is my
